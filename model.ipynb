# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("./datasets/Telco-Customer-Churn.csv")

# %%
# learn about data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
# drop unnecessary columns
df.drop(["customerID"], axis=1, inplace=True)

# %%
# Preprocess columns and handle missing values
df["TotalCharges"] = df["TotalCharges"].replace(' ', 0.)

# %%
df = df.astype({"TotalCharges": "float64"})

# %%
df.iloc[:, 2:].select_dtypes(include=["object"])
# Out:
#      Partner Dependents PhoneService     MultipleLines InternetService  \
# 0        Yes         No           No  No phone service             DSL
# 1         No         No          Yes                No             DSL
# 2         No         No          Yes                No             DSL
# 3         No         No           No  No phone service             DSL
# 4         No         No          Yes                No     Fiber optic
# ...      ...        ...          ...               ...             ...
# 7038     Yes        Yes          Yes               Yes             DSL
# 7039     Yes        Yes          Yes               Yes     Fiber optic
# 7040     Yes        Yes           No  No phone service             DSL
# 7041     Yes         No          Yes               Yes     Fiber optic
# 7042      No         No          Yes                No     Fiber optic
#
#      OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 0                No          Yes               No          No          No
# 1               Yes           No              Yes          No          No
# 2               Yes          Yes               No          No          No
# 3               Yes           No              Yes         Yes          No
# 4                No           No               No          No          No
# ...             ...          ...              ...         ...         ...
# 7038            Yes           No              Yes         Yes         Yes
# 7039             No          Yes              Yes          No         Yes
# 7040            Yes           No               No          No          No
# 7041             No           No               No          No          No
# 7042            Yes           No              Yes         Yes         Yes
#
#      StreamingMovies        Contract PaperlessBilling  \
# 0                 No  Month-to-month              Yes
# 1                 No        One year               No
# 2                 No  Month-to-month              Yes
# 3                 No        One year               No
# 4                 No  Month-to-month              Yes
# ...              ...             ...              ...
# 7038             Yes        One year              Yes
# 7039             Yes        One year              Yes
# 7040              No  Month-to-month              Yes
# 7041              No  Month-to-month              Yes
# 7042             Yes        Two year              Yes
#
#                   PaymentMethod Churn
# 0              Electronic check    No
# 1                  Mailed check    No
# 2                  Mailed check   Yes
# 3     Bank transfer (automatic)    No
# 4              Electronic check   Yes
# ...                         ...   ...
# 7038               Mailed check    No
# 7039    Credit card (automatic)    No
# 7040           Electronic check    No
# 7041               Mailed check   Yes
# 7042  Bank transfer (automatic)    No
#
# [7043 rows x 15 columns]

# %%
# Yes No Columns
binary_columns = ["Partner", "Dependents", "PhoneService", "OnlineSecurity", "OnlineBackup", "DeviceProtection", "TechSupport", "StreamingTV", "StreamingMovies", "PaperlessBilling", "Churn"]

# %%
df[binary_columns].memory_usage(deep=True)
# Out:
# Index                  132
# Partner             418939
# Dependents          417647
# PhoneService        421898
# OnlineSecurity      443498
# OnlineBackup        443908
# DeviceProtection    443901
# TechSupport         443523
# StreamingTV         444186
# StreamingMovies     444211
# PaperlessBilling    419708
# Churn               417406
# dtype: int64

# %%
df[binary_columns] = df[binary_columns].replace({"Yes": 1, "No": 0})
# Out:
# /var/folders/mh/bg9wdjw13b36vqytnysdkv2m0000gn/T/ipykernel_20238/733098078.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[binary_columns] = df[binary_columns].replace({"Yes": 1, "No": 0})

# %%
# turn the binary columns into bool
df[binary_columns] = df[binary_columns].apply(lambda x: x.astype(bool))

# %%
df
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0     Female              0     True       False       1         False
# 1       Male              0    False       False      34          True
# 2       Male              0    False       False       2          True
# 3       Male              0    False       False      45         False
# 4     Female              0    False       False       2          True
# ...      ...            ...      ...         ...     ...           ...
# 7038    Male              0     True        True      24          True
# 7039  Female              0     True        True      72          True
# 7040  Female              0     True        True      11         False
# 7041    Male              1     True       False       4          True
# 7042    Male              0    False       False      66          True
#
#          MultipleLines InternetService  OnlineSecurity  OnlineBackup  \
# 0     No phone service             DSL           False          True
# 1                   No             DSL            True         False
# 2                   No             DSL            True          True
# 3     No phone service             DSL            True         False
# 4                   No     Fiber optic           False         False
# ...                ...             ...             ...           ...
# 7038               Yes             DSL            True         False
# 7039               Yes     Fiber optic           False          True
# 7040  No phone service             DSL            True         False
# 7041               Yes     Fiber optic           False         False
# 7042                No     Fiber optic            True         False
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# 0                False        False        False            False
# 1                 True        False        False            False
# 2                False        False        False            False
# 3                 True         True        False            False
# 4                False        False        False            False
# ...                ...          ...          ...              ...
# 7038              True         True         True             True
# 7039              True        False         True             True
# 7040             False        False        False            False
# 7041             False        False        False            False
# 7042              True         True         True             True
#
#             Contract  PaperlessBilling              PaymentMethod  \
# 0     Month-to-month              True           Electronic check
# 1           One year             False               Mailed check
# 2     Month-to-month              True               Mailed check
# 3           One year             False  Bank transfer (automatic)
# 4     Month-to-month              True           Electronic check
# ...              ...               ...                        ...
# 7038        One year              True               Mailed check
# 7039        One year              True    Credit card (automatic)
# 7040  Month-to-month              True           Electronic check
# 7041  Month-to-month              True               Mailed check
# 7042        Two year              True  Bank transfer (automatic)
#
#       MonthlyCharges  TotalCharges  Churn
# 0              29.85         29.85  False
# 1              56.95       1889.50  False
# 2              53.85        108.15   True
# 3              42.30       1840.75  False
# 4              70.70        151.65   True
# ...              ...           ...    ...
# 7038           84.80       1990.50  False
# 7039          103.20       7362.90  False
# 7040           29.60        346.45  False
# 7041           74.40        306.60   True
# 7042          105.65       6844.50  False
#
# [7043 rows x 20 columns]

# %%
df["SeniorCitizen"] = df["SeniorCitizen"].astype("bool")

# %%
df[binary_columns].memory_usage(deep=True)
# reduction in memory is achieved.
# Out:
# Index                132
# Partner             7043
# Dependents          7043
# PhoneService        7043
# OnlineSecurity      7043
# OnlineBackup        7043
# DeviceProtection    7043
# TechSupport         7043
# StreamingTV         7043
# StreamingMovies     7043
# PaperlessBilling    7043
# Churn               7043
# dtype: int64

# %%
df["gender"].memory_usage(deep=True)
# Out:
# 436731

# %%
df["gender"] = df["gender"].map({"Male": 0, "Female": 1}).astype("bool")
# True means Female and False means Male

# %%
# Create the features and targets
X = df.drop("Churn", axis=1)
y = df["Churn"]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   bool
#  1   SeniorCitizen     7043 non-null   bool
#  2   Partner           7043 non-null   bool
#  3   Dependents        7043 non-null   bool
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   bool
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   bool
#  9   OnlineBackup      7043 non-null   bool
#  10  DeviceProtection  7043 non-null   bool
#  11  TechSupport       7043 non-null   bool
#  12  StreamingTV       7043 non-null   bool
#  13  StreamingMovies   7043 non-null   bool
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   bool
#  16  PaymentMethod     7043 non-null   object
#  17  MonthlyCharges    7043 non-null   float64
#  18  TotalCharges      7043 non-null   float64
# dtypes: bool(12), float64(2), int64(1), object(4)
# memory usage: 467.8+ KB

# %%
# Create train and test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=73, stratify=y)

# %%
numeric_features = X.select_dtypes(include=["int64", "float64"]).columns.tolist()
bool_features = X.select_dtypes(include=["bool"]).columns.tolist()
object_features = X.select_dtypes(include=["object"]).columns.tolist()

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("numeric", StandardScaler(), numeric_features),
        ("object", OneHotEncoder(handle_unknown="ignore"), object_features),
        ("bool", "passthrough", bool_features)
    ]
)

# %%
pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("classifier", RandomForestClassifier())
])

# %%
param_grid = [
    {
        "classifier": [LogisticRegression(class_weight="balanced")],
        "classifier__C": [1],
        "classifier__solver": ["liblinear"]
    },
    {
        "classifier": [RandomForestClassifier(class_weight="balanced")],
        "classifier__n_estimators": [100, 200],
        "classifier__max_depth": [5, 10]
    },
    {
        "classifier": [GradientBoostingClassifier()],
        "classifier__n_estimators": [200, 250],
        "classifier__learning_rate": [0.1],
        "classifier__max_depth": [3, 5]
    },
    {
        "classifier": [SVC(class_weight="balanced")],
        "classifier__C": [0.1, 1],
        "classifier__kernel": ["linear"]
    }
]

# %%
grid = GridSearchCV(pipeline, param_grid, cv=5, scoring="f1")
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('numeric',
#                                                                          StandardScaler(),
#                                                                          ['tenure',
#                                                                           'MonthlyCharges',
#                                                                           'TotalCharges']),
#                                                                         ('object',
#                                                                          OneHotEncoder(handle_unknown='ignore'),
#                                                                          ['MultipleLines',
#                                                                           'InternetService',
#                                                                           'Contract',
#                                                                           'PaymentMethod']),
#                                                                         ('bool',
#                                                                          'passthrough',
#                                                                          ['gender',
#                                                                           'SeniorCitizen',
#                                                                           'Partner',
#                                                                           'Dependents',
#                                                                           'P...
#                          {'classifier': [RandomForestClassifier(class_weight='balanced')],
#                           'classifier__max_depth': [5, 10],
#                           'classifier__n_estimators': [100, 200]},
#                          {'classifier': [GradientBoostingClassifier()],
#                           'classifier__learning_rate': [0.1],
#                           'classifier__max_depth': [3, 5],
#                           'classifier__n_estimators': [200, 250]},
#                          {'classifier': [SVC(class_weight='balanced')],
#                           'classifier__C': [0.1, 1],
#                           'classifier__kernel': ['linear']}],
#              scoring='f1')

# %%
y_pred = grid.best_estimator_.predict(X_test)

# %%
print(f"Best Estimator based on F1 Score")
print("Accuracy:", accuracy_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# Best Estimator based on F1 Score
# Accuracy: 0.7395315826827538
# F1 Score: 0.6157068062827226
#               precision    recall  f1-score   support
#
#        False       0.90      0.72      0.80      1035
#         True       0.51      0.79      0.62       374
#
#     accuracy                           0.74      1409
#    macro avg       0.70      0.75      0.71      1409
# weighted avg       0.80      0.74      0.75      1409
#
# [[748 287]
#  [ 80 294]]

# %%
# find out which features are more important and eliminate the ones with least impact
feature_importances = grid.best_estimator_["classifier"].coef_[0]

# %%
feature_names = grid.best_estimator_[:-1].get_feature_names_out()

# %%
coef_df = pd.DataFrame({
    "Feature": feature_names,
    "Feature Importance": feature_importances,
    "ABS(Feature Importance)": abs(feature_importances)
}).sort_values(by="ABS(Feature Importance)", ascending=False).reset_index(drop=True)

# %%
coef_df["Feature"].head(10)
# Now train the model only with this features.

new_features = ["tenure", "Contract", "TotalCharges", "InternetService", "OnlineSecurity", "PaperlessBilling", "TechSupport", "PhoneService"]

# %%
new_X = df[new_features]

# %%
new_X_train, new_X_test, new_y_train, new_y_test = train_test_split(new_X, y, test_size=0.2, random_state=73, stratify=y)

# %%
numeric_features = new_X.select_dtypes(include=["int64", "float64"]).columns.tolist()
bool_features = new_X.select_dtypes(include=["bool"]).columns.tolist()
object_features = new_X.select_dtypes(include=["object"]).columns.tolist()

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("numeric", StandardScaler(), numeric_features),
        ("object", OneHotEncoder(handle_unknown="ignore"), object_features),
        ("bool", "passthrough", bool_features)
    ]
)

# %%
new_pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("classifier", LogisticRegression(class_weight="balanced"))
])

# %%
new_param_grid = [
    {
        "classifier": [LogisticRegression(class_weight="balanced")],
        "classifier__penalty": ["l2"],  # type of regularization
        "classifier__C": [0.01, 0.1, 1, 10, 100],
        "classifier__solver": ["liblinear", "lbfgs"]
    },
    {
        "classifier": [RandomForestClassifier(class_weight="balanced")],
        "classifier__n_estimators": [100, 200, 300],
        "classifier__max_depth": [5, 8, 10, 15]
    },
    {
        "classifier": [GradientBoostingClassifier()],
        "classifier__n_estimators": [200, 250],
        "classifier__learning_rate": [0.1, 0.5],
        "classifier__max_depth": [3, 5, 10]
    },
    {
        "classifier": [SVC(class_weight="balanced")],
        "classifier__C": [0.1, 1],
        "classifier__kernel": ["linear"]
    }
]

# %%
grid = GridSearchCV(new_pipeline, new_param_grid, cv=5, scoring="f1")
grid.fit(new_X_train, new_y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('numeric',
#                                                                          StandardScaler(),
#                                                                          ['tenure',
#                                                                           'TotalCharges']),
#                                                                         ('object',
#                                                                          OneHotEncoder(handle_unknown='ignore'),
#                                                                          ['Contract',
#                                                                           'InternetService']),
#                                                                         ('bool',
#                                                                          'passthrough',
#                                                                          ['OnlineSecurity',
#                                                                           'PaperlessBilling',
#                                                                           'TechSupport',
#                                                                           'PhoneService'])])),
#                                        ('classifier',
#                                         LogisticRegress...
#                          {'classifier': [RandomForestClassifier(class_weight='balanced')],
#                           'classifier__max_depth': [5, 8, 10, 15],
#                           'classifier__n_estimators': [100, 200, 300]},
#                          {'classifier': [GradientBoostingClassifier()],
#                           'classifier__learning_rate': [0.1, 0.5],
#                           'classifier__max_depth': [3, 5, 10],
#                           'classifier__n_estimators': [200, 250]},
#                          {'classifier': [SVC(class_weight='balanced')],
#                           'classifier__C': [0.1, 1],
#                           'classifier__kernel': ['linear']}],
#              scoring='f1')

# %%
new_y_pred = grid.best_estimator_.predict(new_X_test)

# %%
print(f"Best Estimator based on F1 Score")
print("Accuracy:", accuracy_score(new_y_test, new_y_pred))
print("F1 Score:", f1_score(new_y_test, new_y_pred))
print(classification_report(new_y_test, new_y_pred))
print(confusion_matrix(new_y_test, new_y_pred))
# Out:
# Best Estimator based on F1 Score
# Accuracy: 0.7743080198722498
# F1 Score: 0.6410835214446953
#               precision    recall  f1-score   support
#
#        False       0.90      0.78      0.84      1035
#         True       0.55      0.76      0.64       374
#
#     accuracy                           0.77      1409
#    macro avg       0.73      0.77      0.74      1409
# weighted avg       0.81      0.77      0.78      1409
#
# [[807 228]
#  [ 90 284]]

# %% [markdown]
# There is slighltly an improvement

# %%
cv_df = pd.DataFrame(grid.cv_results_)

# %%
cv_df.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.009292      0.003128         0.004089        0.001991
# 1       0.004813      0.000726         0.002008        0.000155
# 2       0.005098      0.000074         0.001938        0.000030
# 3       0.005887      0.000224         0.001950        0.000035
# 4       0.005248      0.000101         0.001943        0.000020
#
#                               param_classifier  param_classifier__C  \
# 0  LogisticRegression(class_weight='balanced')                 0.01
# 1  LogisticRegression(class_weight='balanced')                 0.01
# 2  LogisticRegression(class_weight='balanced')                 0.10
# 3  LogisticRegression(class_weight='balanced')                 0.10
# 4  LogisticRegression(class_weight='balanced')                 1.00
#
#   param_classifier__penalty param_classifier__solver  \
# 0                        l2                liblinear
# 1                        l2                    lbfgs
# 2                        l2                liblinear
# 3                        l2                    lbfgs
# 4                        l2                liblinear
#
#    param_classifier__max_depth  param_classifier__n_estimators  ...  \
# 0                          NaN                             NaN  ...
# 1                          NaN                             NaN  ...
# 2                          NaN                             NaN  ...
# 3                          NaN                             NaN  ...
# 4                          NaN                             NaN  ...
#
#    param_classifier__kernel  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
#                                               params split0_test_score  \
# 0  {'classifier': LogisticRegression(class_weight...          0.623545
# 1  {'classifier': LogisticRegression(class_weight...          0.627907
# 2  {'classifier': LogisticRegression(class_weight...          0.629962
# 3  {'classifier': LogisticRegression(class_weight...          0.629962
# 4  {'classifier': LogisticRegression(class_weight...          0.629299
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.633288           0.630769           0.621053           0.601840
# 1           0.626016           0.633075           0.619236           0.599736
# 2           0.629183           0.629583           0.613368           0.599212
# 3           0.630027           0.630380           0.613368           0.599476
# 4           0.638411           0.627204           0.627249           0.601290
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.622099        0.011081               13
# 1         0.621194        0.011608               14
# 2         0.620262        0.012257               16
# 3         0.620643        0.012415               15
# 4         0.624691        0.012409               11
#
# [5 rows x 21 columns]

# %%
results = pd.DataFrame(grid.cv_results_)
(results.sort_values(by="mean_test_score", ascending=False)
    [["param_classifier", "param_classifier__max_depth", "param_classifier__n_estimators", "mean_test_score"]].head(10))
# Out:
#                                    param_classifier  \
# 14  RandomForestClassifier(class_weight='balanced')
# 10  RandomForestClassifier(class_weight='balanced')
# 15  RandomForestClassifier(class_weight='balanced')
# 12  RandomForestClassifier(class_weight='balanced')
# 6       LogisticRegression(class_weight='balanced')
# 7       LogisticRegression(class_weight='balanced')
# 8       LogisticRegression(class_weight='balanced')
# 13  RandomForestClassifier(class_weight='balanced')
# 9       LogisticRegression(class_weight='balanced')
# 5       LogisticRegression(class_weight='balanced')
#
#     param_classifier__max_depth  param_classifier__n_estimators  \
# 14                          8.0                           200.0
# 10                          5.0                           100.0
# 15                          8.0                           300.0
# 12                          5.0                           300.0
# 6                           NaN                             NaN
# 7                           NaN                             NaN
# 8                           NaN                             NaN
# 13                          8.0                           100.0
# 9                           NaN                             NaN
# 5                           NaN                             NaN
#
#     mean_test_score
# 14         0.630011
# 10         0.628886
# 15         0.626628
# 12         0.626305
# 6          0.625690
# 7          0.625534
# 8          0.625529
# 13         0.625413
# 9          0.625204
# 5          0.625022

# %%
(results.sort_values(by="mean_fit_time", ascending=False)
    [["param_classifier", "param_classifier__max_depth", "param_classifier__n_estimators", "mean_fit_time"]]
)
# Out:
#                                    param_classifier  \
# 27                     GradientBoostingClassifier()
# 33                     GradientBoostingClassifier()
# 26                     GradientBoostingClassifier()
# 32                     GradientBoostingClassifier()
# 25                     GradientBoostingClassifier()
# 31                     GradientBoostingClassifier()
# 24                     GradientBoostingClassifier()
# 30                     GradientBoostingClassifier()
# 23                     GradientBoostingClassifier()
# 29                     GradientBoostingClassifier()
# 21  RandomForestClassifier(class_weight='balanced')
# 18  RandomForestClassifier(class_weight='balanced')
# 22                     GradientBoostingClassifier()
# 28                     GradientBoostingClassifier()
# 15  RandomForestClassifier(class_weight='balanced')
# 20  RandomForestClassifier(class_weight='balanced')
# 12  RandomForestClassifier(class_weight='balanced')
# 17  RandomForestClassifier(class_weight='balanced')
# 14  RandomForestClassifier(class_weight='balanced')
# 11  RandomForestClassifier(class_weight='balanced')
# 19  RandomForestClassifier(class_weight='balanced')
# 16  RandomForestClassifier(class_weight='balanced')
# 34                     SVC(class_weight='balanced')
# 35                     SVC(class_weight='balanced')
# 13  RandomForestClassifier(class_weight='balanced')
# 10  RandomForestClassifier(class_weight='balanced')
# 0       LogisticRegression(class_weight='balanced')
# 3       LogisticRegression(class_weight='balanced')
# 6       LogisticRegression(class_weight='balanced')
# 4       LogisticRegression(class_weight='balanced')
# 8       LogisticRegression(class_weight='balanced')
# 9       LogisticRegression(class_weight='balanced')
# 7       LogisticRegression(class_weight='balanced')
# 5       LogisticRegression(class_weight='balanced')
# 2       LogisticRegression(class_weight='balanced')
# 1       LogisticRegression(class_weight='balanced')
#
#     param_classifier__max_depth  param_classifier__n_estimators  mean_fit_time
# 27                         10.0                           250.0       1.963680
# 33                         10.0                           250.0       1.942193
# 26                         10.0                           200.0       1.640995
# 32                         10.0                           200.0       1.556067
# 25                          5.0                           250.0       0.868180
# 31                          5.0                           250.0       0.854686
# 24                          5.0                           200.0       0.713975
# 30                          5.0                           200.0       0.683216
# 23                          3.0                           250.0       0.553770
# 29                          3.0                           250.0       0.531175
# 21                         15.0                           300.0       0.517195
# 18                         10.0                           300.0       0.450879
# 22                          3.0                           200.0       0.445636
# 28                          3.0                           200.0       0.424335
# 15                          8.0                           300.0       0.388806
# 20                         15.0                           200.0       0.340737
# 12                          5.0                           300.0       0.305174
# 17                         10.0                           200.0       0.299580
# 14                          8.0                           200.0       0.260546
# 11                          5.0                           200.0       0.204089
# 19                         15.0                           100.0       0.180526
# 16                         10.0                           100.0       0.150270
# 34                          NaN                             NaN       0.142044
# 35                          NaN                             NaN       0.140926
# 13                          8.0                           100.0       0.131952
# 10                          5.0                           100.0       0.101400
# 0                           NaN                             NaN       0.009292
# 3                           NaN                             NaN       0.005887
# 6                           NaN                             NaN       0.005314
# 4                           NaN                             NaN       0.005248
# 8                           NaN                             NaN       0.005212
# 9                           NaN                             NaN       0.005202
# 7                           NaN                             NaN       0.005192
# 5                           NaN                             NaN       0.005172
# 2                           NaN                             NaN       0.005098
# 1                           NaN                             NaN       0.004813

# %% [markdown]
# - However it is obvious that the Random Forest Classifier has the second longest **mean_fit_time** among all classifiers.
# - It takes longer to train the Random Forest Classifier, but it gives slightly better model compared to the old Logistic Regression model.
